# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import date
from empiricaldist import Pmf
from empiricaldist import Cdf

# %%
df = pd.read_csv('data_music_trends.csv', sep=",", encoding='cp1252')

# %%
df.head(10)
# Out:
#    Unnamed: 0                                       title         artist  \
# 0           1                            Hey, Soul Sister          Train
# 1           2                        Love The Way You Lie         Eminem
# 2           3                                     TiK ToK          Kesha
# 3           4                                 Bad Romance      Lady Gaga
# 4           5                        Just the Way You Are     Bruno Mars
# 5           6                                        Baby  Justin Bieber
# 6           7                                    Dynamite      Taio Cruz
# 7           8                                     Secrets    OneRepublic
# 8           9  Empire State of Mind (Part II) Broken Down    Alicia Keys
# 9          10                    Only Girl (In The World)        Rihanna
#
#          top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 0       neo mellow  2010   97    89    67  -4     8   80  217     19     4
# ...

# %%
df.drop(['Unnamed: 0'], axis= 1, inplace= True)

# %%
df.head()
# Out:
#                   title      artist        top genre  year  bpm  nrgy  dnce  \
# 0      Hey, Soul Sister       Train       neo mellow  2010   97    89    67
# 1  Love The Way You Lie      Eminem  detroit hip hop  2010   87    93    75
# 2               TiK ToK       Kesha        dance pop  2010  120    84    76
# 3           Bad Romance   Lady Gaga        dance pop  2010  119    92    70
# 4  Just the Way You Are  Bruno Mars              pop  2010  109    84    64
#
#    dB  live  val  dur  acous  spch  pop
# 0  -4     8   80  217     19     4   83
# 1  -5    52   64  263     24    23   82
# 2  -3    29   71  200     10    14   80
# 3  -4     8   71  295      0     4   79
# 4  -5     9   43  221      2     4   78

# %%
# Check the dimensions of df

df.shape
# Out:
# (603, 14)

# %%
# Check for null values

df.isnull().sum()
# Out:
# title        0
# artist       0
# top genre    0
# year         0
# bpm          0
# nrgy         0
# dnce         0
# dB           0
# live         0
# val          0
# dur          0
# acous        0
# spch         0
# pop          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 14 columns):
# title        603 non-null object
# artist       603 non-null object
# top genre    603 non-null object
# year         603 non-null int64
# bpm          603 non-null int64
# nrgy         603 non-null int64
# dnce         603 non-null int64
# dB           603 non-null int64
# live         603 non-null int64
# val          603 non-null int64
# dur          603 non-null int64
# acous        603 non-null int64
# spch         603 non-null int64
# pop          603 non-null int64
# dtypes: int64(11), object(3)
# memory usage: 66.0+ KB

# %%
pmf_year = Pmf.from_seq(df['year'], normalize= False)

# Plot the PMF
pmf_year.bar()

# Label the axes
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
pmf_val = Pmf.from_seq(df['val'], normalize= False)

# Plot the PMF
pmf_val.bar()
# Label the axes
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
years = list(df['year'].unique())

for year in years:
    
    data = df[df['year'] == year]

    sns.set(style="ticks")

    f, ax = plt.subplots()

    sns.distplot(data['bpm'], ax=ax, bins= 10)

    sns.despine(ax=ax)
    ax.set_title(year, size= 25) 
    
    plt.show()

# %%
datas = []

for year in range(2010,2020):
    data= df[df['year'] == year]
    datas.append(data)
    
# Create the graphs
    
f, ax = plt.subplots(10, sharex= True, sharey= True)
    
for i in range(0,10):
    sns.distplot(datas[i]['bpm'], ax=ax[i], bins= 10)

# %%
f, ax = plt.subplots()
    
sns.distplot(datas[0]['bpm'], ax=ax, bins= 10)

# %%
g = sns.distplot(df, x='bpm', col='year', col_wrap=3, kde=True, color='green')
g.set_axis_labels(y_var='Density')
g.set(xlim=(0, 1.0), ylim=(0, 3.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-b74a7132ec35> in <module>
# ----> 1 g = sns.distplot(df, x='bpm', col='year', col_wrap=3, kde=True, color='green')
#       2 g.set_axis_labels(y_var='Density')
#       3 g.set(xlim=(0, 1.0), ylim=(0, 3.0))
#
# TypeError: distplot() got an unexpected keyword argument 'x'
